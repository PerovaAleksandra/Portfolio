# %% [markdown]
# # Мобильные приложения — Выделение групп пользователей на основе поведения

# %% [markdown]
# **Цель проекта**
#
# Исследование данных о событиях, совершенных в мобильном приложении "Ненужные вещи", чтобы на основе анализа дать рекомендации, которые позволят улучшить работу приложения.

# %% [markdown]
# **План работы**
# 1. Загрузка датасетов и изучение общей информации
# 2. Предобработка данных
# 2.1. Проверка корректности наименования колонок
# 2.2. Объединение событий
# 2.3. Объединение датасетов
# 2.4. Проверка наличия дубликатов
# 2.5. Проверка пропущенных значений
# 2.6. Изменение типов данных
# 2.7. Выделение сессий пользователей
# 2.8. Выделение времени начала сессии
# 2.9. Выделение информации о событии tips_click
# 3. Исследовательский анализ данных
# 3.1. Retention rate
# 3.2. Время, проведенное в приложении
# 3.3. Частота совершения событий
# 3.4. Конверсия в целевое действие contacts_show
# 4. Сегментация
# 4.1. Сегментация пользователей на основе Retention rate
# 4.2. Сегментация пользователей на основе конверсии
# 5. Проверка гипотез
# 5.1. Группа пользователей, установивших приложение по ссылке из yandex, и группа пользователей, установивших приложение по ссылке из google, демонстрируют разную конверсию в просмотры контактов
# 5.2. Группа пользователей, кликнувших по рекомендованному объявлению, и группа пользователей, не воспользовавшихся функцией рекомендованных объявлений, демонстрируют разную конверсию в просмотры контактов
# Общий вывод

# %% [markdown]
# **Описание данных**:
#
# В датасете содержатся данные пользователей, впервые совершивших действия в приложении после 7 октября 2019 года.
#
# Датасет mobile_dataset.csv содержит колонки:
# •	event.time  — время совершения;
# •	event.name  — название события;
# •	user.id  — идентификатор пользователя.
#
# Датасет mobile_sources.csv содержит колонки:
# •	userId  — идентификатор пользователя;
# •	source  — источник, с которого пользователь установил приложение.
#
# Расшифровки событий:
# •	advert_open  — открытие карточки объявления;
# •	photos_show  — просмотр фотографий в объявлении;
# •	tips_show  — пользователь увидел рекомендованные объявления;
# •	tips_click  — пользователь кликнул по рекомендованному объявлению;
# •	contacts_show  и  show_contacts  — пользователь нажал на кнопку "посмотреть номер
# телефона" на карточке объявления;
# •	contacts_call  — пользователь позвонил по номеру телефона на карточке
# объявления;
# •	map  — пользователь открыл карту размещенных объявлений;
# •	search_1  —  search_7  — разные события, связанные с поиском по сайту;
# •	favorites_add  — добавление объявления в избранное.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# **В ходе анализа данных выявлено следующее:**
# Анализ Retention rate показал, что лучшее удержание показывают пользователи, привлеченные в 41-42 недели, на 43 неделе показатели немного падают и сильно проседают к 44 неделе.
#
# Просмотр данных в разрезе времени, проведенного в приложении, показал, что медиана длительности сессии 482 сек (8 мин). Присутствует большое количество нулевых и аномально долгих сессий.
# Количество нулевых сессий: 1518, что составляет 16.98 %. Количество аномально долгих сессий: 387, что составляет 4.33 %.
# Больше всего нулевых сессий с событиями: показ рекомендованных объявлений и просмотр фотографий в объявлении. Возможно, это следствие технических сбоев.
#
# Также есть тенденция на увеличение количества событий в день. В разрезе дней недели пик частоты свершения событий приходится на начало недели и уменьшается к выходным. Минимальная частота в субботу.
#
# Конверсия в целевое действие по лайфтайму растет, но темпы роста замедляются.
#
#
# Пользователи были разделены на три группы:
# •	пользователи, установившие приложение по ссылке из yandex;
# •	пользователи, установившие приложение по ссылке из google;
# •	пользователи, установившие приложение из других источников.
#
#
#
# **Анализ удержания и конверсии по группам показал:**
# Пользователи google показывают хороше удержание на 6-7 день, но на 13 результат заметно хуже других групп. Пользователи yandex показывают наиболее плавное удержание, без всплесков. Пользователи, установившие приложение из других источников, наиболее активны во 2 и 5 дни.
# Явных лидеров по удержанию среди пользователей, установивших приложения из разных истоников, нет.
# Явные лидеры по конверсии - пользователи, установившие приложение по ссылке из yandex. Немного отстают пользователи google. Конверсия пользователей, установивших приложение из других источников, значительно ниже.
#
#
#
# **На основе проведенного анализа и выдвинутых ранее предположений были сформулированы следующие гипотезы:**
# Группа пользователей, установивших приложение по ссылке из yandex, и группа пользователей, установивших приложение по ссылке из google, демонстрируют разную конверсию в просмотры контактов.
# z-тест показал: Разница конверсий между пользователями yandex и пользователями google не является статистически значимой, поэтому можно считать, что группы имеют одинаковую конверсию.
#
# Группа пользователей, кликнувших по рекомендованному объявлению, и группа пользователей, не воспользовавшихся функцией рекомендованных объявлений, демонстрируют разную конверсию в просмотры контактов
# z-тест показал: Разница конверсий между пользователями, выбравшими рекомендованное объявление, и пользователями, не воспользовавшихся функцией рекомендованных объявлений, является статистически значимой, поэтому можно считать, что у групп разная конверсия.
#
# **Рекомендации**: в процессе работы выявлено большое количество нулевых сессий с событиями:
# - показ рекомендованных объвлений;
# - просмотр фотографий в объявлении.
#
# Возможно, есть технические сбои.

# %%
# загружаем библиотеки
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sns
import math
import scipy.stats as st

# %% [markdown]
# ## 1. Загрузка датасетов и изучение общей информации

# %%
# изучим файл mobile_sourсes
mobile_sourсes = pd.read_csv('https://code.s3.yandex.net/datasets/mobile_soures.csv')
mobile_sourсes.head()
# Out:
#                                  userId  source
# 0  020292ab-89bc-4156-9acf-68bc2783f894   other
# 1  cf7eda61-9349-469f-ac27-e5b6f5ec475c  yandex
# 2  8c356c42-3ba9-4cb6-80b8-3f868d0192c3  yandex
# 3  d9b06b47-0f36-419b-bbb0-3533e582a6cb   other
# 4  f32e1e2a-3027-4693-b793-b7b3ff274439  google

# %%
mobile_sourсes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4293 entries, 0 to 4292
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   userId  4293 non-null   object
#  1   source  4293 non-null   object
# dtypes: object(2)
# memory usage: 67.2+ KB

# %%
# изучим файл mobile_dataset
mobile_dataset = pd.read_csv('https://code.s3.yandex.net/datasets/mobile_dataset.csv')
mobile_dataset.head()
# Out:
#                    event.time   event.name  \
# 0  2019-10-07 00:00:00.431357  advert_open
# 1  2019-10-07 00:00:01.236320    tips_show
# 2  2019-10-07 00:00:02.245341    tips_show
# 3  2019-10-07 00:00:07.039334    tips_show
# 4  2019-10-07 00:00:56.319813  advert_open
#
#                                 user.id
# 0  020292ab-89bc-4156-9acf-68bc2783f894
# 1  020292ab-89bc-4156-9acf-68bc2783f894
# 2  cf7eda61-9349-469f-ac27-e5b6f5ec475c
# 3  020292ab-89bc-4156-9acf-68bc2783f894
# 4  cf7eda61-9349-469f-ac27-e5b6f5ec475c

# %%
mobile_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74197 entries, 0 to 74196
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   event.time  74197 non-null  object
#  1   event.name  74197 non-null  object
#  2   user.id     74197 non-null  object
# dtypes: object(3)
# memory usage: 1.7+ MB

# %% [markdown]
# В исходных данных отсутствует разделение по сессиям пользователей.

# %%
# посмотрим названия событий
mobile_dataset['event.name'].value_counts().sort_index()
# Out:
# advert_open       6164
# contacts_call      541
# contacts_show     4450
# favorites_add     1417
# map               3881
# photos_show      10012
# search_1          3506
# search_2           324
# search_3           522
# search_4           701
# search_5          1049
# search_6           460
# search_7           222
# show_contacts       79
# tips_click         814
# tips_show        40055
# Name: event.name, dtype: int64

# %% [markdown]
# Есть два события с одним значением contacts_show и show_contacts. Нужно их объединить.

# %%
# определим период, который был дан для анализа
print('Начальная дата:', mobile_dataset['event.time'].min())
print('Конечная дата:', mobile_dataset['event.time'].max())

# посчитаем количество уникальных польузователей
print('Количество уникальных пользователей:', mobile_dataset['user.id'].nunique())
# Out:
# Начальная дата: 2019-10-07 00:00:00.431357
# Конечная дата: 2019-11-03 23:58:12.532487
# Количество уникальных пользователей: 4293

# %% [markdown]
# Необходимо:
# •	изменить названия столбцов;
# •	объединить события;
# •	объединить датасеты;
# •	проверить наличие явных дубликатов;
# •	найти пропущенные значения;
# •	изменить тип данных столбца даты и времени;
# •	выделить сессии пользователей;
# •	определить время начала каждой сессии;
# •	определить дату первой активности.

# %% [markdown]
# ## 2. Предобработка данных

# %%
# изменяем названия столбцов
mobile_dataset.columns = ['event_time', 'event_name', 'user_id']
mobile_sourсes.columns = ['user_id', 'source']

# %%
# заменяем событие show_contacts на contacts_show
mobile_dataset['event_name'].replace('show_contacts', 'contacts_show', inplace=True)

# %%
# объединяем датасеты по столбцу user_id
data = mobile_dataset.merge(mobile_sourсes, on='user_id', how='left')

# %%
# проверяем наличие явных дубликатов
data.duplicated().sum()
# Out:
# 0

# %%
# ищем пропущенные значения
data.isna().sum()
# Out:
# event_time    0
# event_name    0
# user_id       0
# source        0
# dtype: int64

# %%
# изменяем тип данных столбца event_time
data['event_time'] = pd.to_datetime(mobile_dataset['event_time']).dt.round('1S')

# %% [markdown]
# Выделим сессии относительно тайм-аута 2 часа. Этого времени достаточно, чтобы пользователь начал новую по смыслу сессию.

# %%
# сортируем датасет по id пользователя и времени события
data = data.sort_values(['user_id', 'event_time']) 

# разбиваем данные на группы с тайм-аутом 120 минут
g = (data.groupby('user_id')['event_time'].diff() > pd.Timedelta('120Min')).cumsum()

# добавляем столбец с номером группы
data['session_id'] = data.groupby(['user_id', g], sort=False).ngroup() + 1

# %% [markdown]
# Так как датафрейм уже отсортирован по id пользователя и времени совершения события, временем начала сессии будет являться первое значение event_time в группе

# %%
# отбираем время первого события в группе, это будет время начала сессии
session_start = data.groupby('session_id', as_index=False).agg({'event_time':'first'})

# присоединяем время начала сессии к осноному датафрейму
data = data.merge(session_start, on='session_id', how='left')

# переименовываем названия стобцов
data.columns = ['event_time', 'event_name', 'user_id', 'source', 'session_id', 'session_start']

# %% [markdown]
# Выведем в отдельный столбец информацию о том, кликнул ли пользователь по время сессии в рекомендованное объявление

# %%
# отбираем пользователей с действием tips_click
favorites = list(data.query('event_name == "tips_click"')['user_id'].unique())

# создаем функцию, которая будет присваивать значение 
def age_group(age):
    if age in favorites:
        return 'tips_click'
    else:
        return 'not_tips_click'
    
# создаем новый столбец
data['favorites'] = data['user_id'].apply(age_group)

# %% [markdown]
# В ходе предобработки данных были заменены названия столбцов, изменен тип данных столбца event_time, объединены события show_contacts на contacts_show и объединены исходные датасеты.
# Также выделены сессии относительно тайм-аута 2 часа и проставлен признак действия tips_click.
# Дубликатов и пропусков не обнаружено.

# %% [markdown]
# ## 3. Исследовательский анализ данных

# %%
# определим минимальную и максимальную даты предоставленного датасета
print('Минимальная дата:', data['event_time'].min())
print('Максимальная дата:', data['event_time'].max())

# определим период данных для анализа
print('Период:', data['event_time'].max()-data['event_time'].min())

# определим количество уникальных пользователей
print('Количество уникальных пользователей:', data['user_id'].nunique())

# определим количество сессий
print('Всего количество сессий:', data['session_id'].nunique())
# Out:
# Минимальная дата: 2019-10-07 00:00:00
# Максимальная дата: 2019-11-03 23:58:13
# Период: 27 days 23:58:13
# Количество уникальных пользователей: 4293
# Всего количество сессий: 8941

# %% [markdown]
# ### 3.1. Retention rate

# %%
# создаем функцию пользовательских профилей
def get_profiles(data):

    # находим параметры первых посещений
    profiles = (
        data.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'source': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')
    profiles['week'] = profiles['first_ts'].dt.isocalendar().week
      

    return profiles

# %%
profiles = get_profiles(data)
profiles.head()
# Out:
#                                 user_id            first_ts  source  \
# 0  0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-07 13:39:46   other
# 1  00157779-810c-4498-9e05-a1e9e3cedf93 2019-10-19 21:34:34  yandex
# 2  00463033-5717-4bf1-91b4-09183923b9df 2019-11-01 13:54:35  yandex
# 3  004690c3-5a84-4bb7-a8af-e0c8f8fca64e 2019-10-18 22:14:06  google
# 4  00551e79-152e-4441-9cf7-565d7eb04090 2019-10-25 16:44:41  yandex
#
#            dt               month  week
# 0  2019-10-07 2019-10-07 13:39:46    41
# 1  2019-10-19 2019-10-19 21:34:34    42
# 2  2019-11-01 2019-11-01 13:54:35    44
# 3  2019-10-18 2019-10-18 22:14:06    42
# 4  2019-10-25 2019-10-25 16:44:41    43

# %%
# создаем функцию расчета удержания
def get_retention(
    profiles,
    data,
    observation_date,
    horizon_days,
    dimensions=[], 
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        data[['user_id', 'session_start', 'favorites']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # рассчитываем удержание
    result_grouped = result_raw.pivot_table(
        index=dimensions, 
        columns='lifetime',
        values='user_id',
        aggfunc='nunique',
    )
    cohort_sizes = (
        result_raw.groupby(dimensions) 
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'cohort_size'})
    )
    result_grouped = cohort_sizes.merge(
        result_grouped, on=dimensions, how='left'  
    ).fillna(0)
    result_grouped = result_grouped.div(result_grouped['cohort_size'], axis=0)

    # исключаем все лайфтаймы, превышающие горизонт анализа
    result_grouped = result_grouped[
        ['cohort_size'] + list(range(horizon_days))
    ]

    # восстанавливаем столбец с размерами когорт
    result_grouped['cohort_size'] = cohort_sizes

    # возвращаем таблицу удержания и сырые данные
    return result_raw, result_grouped

# %%
# устанавливаем момент и горизонт анализа
observation_date =  profiles['dt'].max()
horizon_days = 7

# %%
# запускаем функцию расчета удержания по неделям
retention_raw, retention = get_retention(
    profiles, data, observation_date, horizon_days, dimensions=['week']
) 

# строим тепловую карту
plt.figure(figsize=(15, 6))
sns.heatmap(retention.drop(columns=['cohort_size', 0]), annot=True, fmt='.2%')
plt.title('Тепловая карта удержания')
plt.show()

# %% [markdown]
# Лучшее удержание показывают пользователи, привлеченные в 41-42 недели, на 43 неделе показатели немного падают и сильно проседают к 44 неделе.

# %% [markdown]
# ### 3.2. Время, проведенное в приложении

# %% [markdown]
# Выделим данные о сессиях в отдельный датасет. Добавим время окончания сессии, количество совершенных событий в сессии и длительность.

# %%
# создаем датафрейм с сессиями
sessions = data.groupby(['user_id', 'session_id']).agg({'event_time':['first', 'last'], 
                                                   'event_name':'count'}).reset_index()
# переименовываем стобцы
sessions.columns = ['user_id', 'session_id', 'session_start', 'session_and', 'events_count']

# вычисляем длительность каждой сессии в секундах
sessions['length'] = (sessions['session_and'] - sessions['session_start']).dt.seconds

sessions.head()
# Out:
#                                 user_id  session_id       session_start  \
# 0  0001b1d5-b74a-4cbf-aeb0-7df5947bf349           1 2019-10-07 13:39:46
# 1  0001b1d5-b74a-4cbf-aeb0-7df5947bf349           2 2019-10-09 18:33:56
# 2  0001b1d5-b74a-4cbf-aeb0-7df5947bf349           3 2019-10-21 19:52:31
# 3  0001b1d5-b74a-4cbf-aeb0-7df5947bf349           4 2019-10-22 11:18:15
# 4  00157779-810c-4498-9e05-a1e9e3cedf93           5 2019-10-19 21:34:34
#
#           session_and  events_count  length
# 0 2019-10-07 13:49:42             9     596
# 1 2019-10-09 18:42:23             4     507
# 2 2019-10-21 20:07:30            14     899
# 3 2019-10-22 11:30:53             8     758
# 4 2019-10-19 21:59:55             9    1521

# %%
# посмотрим на длительность сессий на графике
plt.figure(figsize =(13, 5))
sessions['length'].hist(bins=30)
plt.title('Гистограмма длительности сессий')
plt.xlabel('Длина сессии, сек')
plt.ylabel('Количество сессий')
plt.grid()
plt.show()

# %%
# посмотрим характеристики длительности сессии
sessions['length'].describe()
# Out:
# count     8941.000000
# mean      1488.382060
# std       2685.469392
# min          0.000000
# 25%         64.000000
# 50%        482.000000
# 75%       1598.000000
# max      39115.000000
# Name: length, dtype: float64

# %% [markdown]
# Средняя длина сессии 1488 сек, в то время как медиана 482 сек.

# %% [markdown]
# Много нулевых и аномально долгих сессий. Посчитаем их количество.
# За аномально долгую сессию примем сессию длительностью свыше 2 часов, т.е. 7200 секунд.

# %%
# рассчитываем количество и процент нулевых сессий
sessions_min = sessions.query('length == 0')
print('Количество нулевых сессий:', len(sessions_min))
print('Процент нулевых сессий:', round(len(sessions_min)/len(sessions['user_id'])*100, 2))

# рассчитываем количество и процент аномально долгих сессий
sessions_max = sessions.query('length > 7200')
print('Количество аномально долгих сессий:', len(sessions_max))
print('Процент аномально долгих сессий:', round(len(sessions_max)/len(sessions['user_id'])*100, 2))
# Out:
# Количество нулевых сессий: 1518
# Процент нулевых сессий: 16.98
# Количество аномально долгих сессий: 387
# Процент аномально долгих сессий: 4.33

# %%
# расмотрим нулевые сессии в разрезе соверешнных событий
# объединим датасеты
data = data.merge(sessions[['session_and', 'events_count', 'length','session_id']], on='session_id', how='left')

# посмотрим, какие события происходили в нулевых сессиях
data.query('length == 0')['event_name'].value_counts()
# Out:
# tips_show        611
# photos_show      431
# search_1         263
# contacts_show     91
# map               75
# advert_open       34
# search_5          18
# favorites_add     18
# search_3           5
# tips_click         4
# search_7           3
# search_4           3
# Name: event_name, dtype: int64

# %% [markdown]
# Больше всего нулевых сессий с событиями:
# - показ рекомендованных объвлений;
# - просмотр фотографий в объявлении.
#
# Возможно, есть технические сбои.

# %% [markdown]
# Медиана длительности сессии 482 сек (8 мин). Присутствует большое количество нулевых и аномально долгих сессий.
# Количество нулевых сессий: 1518, что составляет 16.98 %. Количество аномально долгих сессий: 387, что составляет 4.33 %.
# Больше всего нулевых сессий с событиями: показ рекомендованных объявлений и просмотр фотографий в объявлении.
# Возможно, это следствие технических сбоев.

# %% [markdown]
# ### 3.3. Частота совершения событий

# %%
# построим гистограмму частоты совершения событий по дате и времени
plt.figure(figsize =(13, 5))
data['event_time'].hist(bins=27)
plt.ylim(1500, 3700)
plt.title('Гистограмма по дате и времени')
plt.xticks(rotation=45)
plt.xlabel('Дата')
plt.ylabel('Количество событий')
plt.grid()
plt.show()

# %% [markdown]
# Есть тепденция на увеличение количества событий в день, но какой-либо закономерности пока не видно.
# Посмотрим данные в разрезе дней недели.

# %%
# добавляем столбец с днем недели совершения события
data.insert(5,'weekday', data['event_time'].dt.weekday)

# %%
plt.figure(figsize =(13, 5))
data['weekday'].hist(bins=7)
plt.ylim(8000, 12000)
plt.title('Гистограмма по дню недели')
plt.xlabel('День недели')
plt.ylabel('Количество событий')
plt.grid()
plt.show()

# %% [markdown]
# Пик частоты свершения событий приходится на начало недели и уменьшается к выходным. Минимальная частота в субботу.

# %% [markdown]
# ### 3.4. Конверсия в целевое действие contacts_show

# %% [markdown]
# Выведем в отдельную таблицу данные по сессиям, в которых произошло целевое действие

# %%
# отбираем строки с целевым действием
target_actions = data.query('event_name == "contacts_show"')

# оставляем id пользователя и время совершения события
target_actions = target_actions[['user_id', 'event_time']]

# переименовываем столбцы
target_actions.columns = ['user_id', 'event_dt']

# %%
# создаем функцию для расчета конверсии

def get_conversion(
    profiles,
    target_actions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_target_actions = (
        target_actions.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_target_actions[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу конверсии
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        # считаем сумму с накоплением для каждой строки
        result = result.fillna(0).cumsum(axis = 1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # добавляем размеры когорт в таблицу конверсии
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# считаем конверсию без параметра dimensions
conversion_raw, conversion, conversion_history = get_conversion(
    profiles, target_actions, observation_date, horizon_days
)


plt.figure(figsize = (16, 10)) # задаём размер «подложки»

# исключаем размеры когорт
# конверсии первого дня различаются, их удалять не нужно
report = conversion.drop(columns = ['cohort_size'])

sns.heatmap(
    report, annot=True, cbar=False, fmt='.1%', ax=plt.subplot(2, 1, 1)
)  # в первой ячейке таблицы графиков строим тепловую карту
plt.title('Тепловая карта конверсии по лайфтайму')
plt.ylabel('')

report.T.plot(
    grid=True, xticks=list(report.columns.values), ax=plt.subplot(2, 1, 2)
)  # во второй — кривые конверсии
plt.title('Кривая конверсии по лайфтайму')

plt.show()

# %% [markdown]
# Конверсия в целевое действие по лайфтайму растет, но темпы роста замедляются.

# %% [markdown]
# Анализ Retention rate показал, что лучшее удержание показывают пользователи, привлеченные в 41-42 недели, на 43 неделе показатели немного падают и сильно проседают к 44 неделе.
#
# Просмотр данных в разрезе времени, проведенного в приложении, показал, что медиана длительности сессии 482 сек (8 мин). Присутствует большое количество нулевых и аномально долгих сессий.
# Количество нулевых сессий: 1518, что составляет 16.98 %. Количество аномально долгих сессий: 387, что составляет 4.33 %.
# Больше всего нулевых сессий с событиями: показ рекомендованных объявлений и просмотр фотографий в объявлении. Возможно, это следствие технических сбоев.
#
# Также есть тенденция на увеличение количества событий в день. В разрезе дней недели пик частоты свершения событий приходится на начало недели и уменьшается к выходным. Минимальная частота в субботу.
#
# Конверсия в целевое действие по лайфтайму растет, но темпы роста замедляются.

# %% [markdown]
# ## 4. Сегментация

# %% [markdown]
# Для пользователей приложения огромное значение имеет удобство процесса выбора товара и его покупки. Сбои в работе, проблемы с регистрацией в приложении, некорректно работающая фильтрация, различные отвлекающие факторы могут помешать этому процессу.
#
# Можно предположить, что приложение плохо адаптировано под какой-либо браузер. В результате чего, снижается удержание пользователей и конверсия в целевое действие. Проведем анализ в разрезе используемого пользователями браузера.

# %% [markdown]
# Разделим пользователей на три группы:
# - пользователи, установившие приложение по ссылке из yandex;
# - пользователи, установившие приложение по ссылке из google;
# - пользователи, установившие приложение из других источников.

# %% [markdown]
# ### 4.1. Сегментация пользователей на основе Retention rate

# %%
# устанавливаем горизонт анализа
horizon_days = 14

# %%
# запускаем функцию расчета удержания по по источнику установки приложения
retention_raw, retention = get_retention(
    profiles, data, observation_date, horizon_days, dimensions=['source']
) 

# строим тепловую карту
plt.figure(figsize=(15, 6))
sns.heatmap(retention.drop(columns=['cohort_size', 0]), annot=True, fmt='.2%')
plt.title('Тепловая карта удержания')
plt.show()

# %%
# строим кривые удержания
report = retention.drop(columns=['cohort_size', 0])
report.T.plot(grid=True, xticks=list(report.columns.values), figsize=(15, 5))
plt.xlabel('Лайфтайм')
plt.title('Кривые удержания с разбивкой по источнику установки приложения')
plt.show()

# %% [markdown]
# ### 4.2. Сегментация пользователей на основе конверсии

# %%
# считаем конверсию без параметра dimensions
conversion_raw, conversion, conversion_history = get_conversion(
    profiles, target_actions, observation_date, horizon_days, dimensions=['source']
)


plt.figure(figsize = (16, 10)) # задаём размер «подложки»

# исключаем размеры когорт
# конверсии первого дня различаются, их удалять не нужно
report = conversion.drop(columns = ['cohort_size'])

sns.heatmap(
    report, annot=True, cbar=False, fmt='.1%', ax=plt.subplot(2, 1, 1)
)  # в первой ячейке таблицы графиков строим тепловую карту
plt.title('Тепловая карта конверсии по лайфтайму')
plt.ylabel('')

report.T.plot(
    grid=True, xticks=list(report.columns.values), ax=plt.subplot(2, 1, 2)
)  # во второй — кривые конверсии
plt.title('Кривая конверсии по лайфтайму')

plt.show()

# %% [markdown]
# Пользователи google показывают хорошие удержание на 6-7 день, но на 13 результат заметно хуже других групп. Пользователи yandex показывают наиболее плавное удержание, без всплесков. Пользователи, установившие приложение из других источников, наиболее активны во 2 и 5 дни.
# Явных лидеров по удержанию среди пользователей, установивших приложения из разных источников, нет.
#
# Явные лидеры по конверсии - пользователи, установившие приложение по ссылке из yandex. Немного отстают пользователи google. Конверсия пользователей, установивших приложение из других источников, значительно ниже.

# %% [markdown]
# ## 5. Проверка гипотез

# %% [markdown]
# ### 5.1. Группа пользователей, установивших приложение по ссылке из yandex, и группа пользователей, установивших приложение по ссылке из google, демонстрируют разную конверсию в просмотры контактов

# %% [markdown]
# H_0: Конверсия пользователей yandex = конверсии пользователей google
# H_a: Конверсия пользователей yandex ≠ конверсии пользователей google
# alpha = 0.05

# %%
# считаем количество пользователей в разрезе групп
users_group = (data.pivot_table(index='source', values='user_id', aggfunc='nunique')
                 .reset_index()
                 .rename(columns={'source': 'group', 'user_id':'users_all'}))

# считаем количество пользователей, совершивших целевое действие, в разрезе групп
users_group_target = (data.query('event_name == "contacts_show"')
                          .pivot_table(index='source', values='user_id', aggfunc='nunique')
                          .reset_index()
                          .rename(columns={'source': 'group', 'user_id':'contacts_show'}))

# объединяем в одну таблицу
group_z_test = users_group_target.merge(users_group, on = 'group', how='left')
group_z_test = group_z_test.drop(labels = [1], axis = 0).reset_index(drop= True)
group_z_test
# Out:
#     group  contacts_show  users_all
# 0  google            275       1129
# 1  yandex            478       1934

# %%
def z_test(df):
    alpha = .05
    contacts_show_a, users_all_a, group_a = df.loc[0, 'contacts_show'], df.loc[0, 'users_all'], df.loc[0, 'group']
    contacts_show_b, users_all_b, group_b = df.loc[1, 'contacts_show'], df.loc[1, 'users_all'], df.loc[1, 'group']

    # пропорция успехов в первой группе:
    p1 = contacts_show_a/users_all_a

    # пропорция успехов во второй группе:
    p2 = contacts_show_b/users_all_b

    # пропорция успехов в комбинированном датасете:
    p_combined = (contacts_show_a + contacts_show_b) / (users_all_a + users_all_b)

    # разница пропорций в датасетах
    difference = p1 - p2 

    # считаем статистику в ст.отклонениях стандартного нормального распределения
    z_value = difference / math.sqrt(p_combined * (1 - p_combined) * (1/users_all_a + 1/users_all_b))

    # задаем стандартное нормальное распределение (среднее 0, ст.отклонение 1)
    distr = st.norm(0, 1)  

    p_value = (1 - distr.cdf(abs(z_value))) * 2

    print('p-значение: ', p_value)

    if p_value < alpha:
        print('Отвергаем нулевую гипотезу, между группами есть статистически значимые различия')
    else:
        print('Не получилось отвергнуть нулевую гипотезу, статистически значимых различий в выборках нет')

# %%
z_test(group_z_test)
# Out:
# p-значение:  0.8244316027993777
# Не получилось отвергнуть нулевую гипотезу, статистически значимых различий в выборках нет

# %% [markdown]
# Разница конверсий между пользователями yandex и пользователями google не является статистически значимой, поэтому можно считать, что группы имеют одинаковую конверсию.

# %% [markdown]
# ### 5.2. Группа пользователей, кликнувших по рекомендованному объявлению, и группа пользователей, не воспользовавшихся функцией рекомендованных объявлений, демонстрируют разную конверсию в просмотры контактов

# %% [markdown]
# H_0: Конверсия пользователей, кликнувших по рекомендованному объявлению = конверсии пользователей, не воспользовавшихся функцией рекомендованных объявлений
# H_a: Конверсия пользователей, кликнувших по рекомендованному объявлению ≠ конверсии пользователей, не воспользовавшихся функцией рекомендованных объявлений
# alpha = 0.05

# %%
# считаем количество пользователей в разрезе групп
users_group_favorites = (data.pivot_table(index='favorites', values='user_id', aggfunc='nunique')
                 .reset_index()
                 .rename(columns={'favorites': 'group', 'user_id':'users_all'}))

# считаем количество пользователей, совершивших целевое действие, в разрезе групп
users_group_target_favorites = (data.query('event_name == "contacts_show"')
                          .pivot_table(index='favorites', values='user_id', aggfunc='nunique')
                          .reset_index()
                          .rename(columns={'favorites': 'group', 'user_id':'contacts_show'}))

# объединяем в одну таблицу
group_z_test_favorites = users_group_target_favorites.merge(users_group_favorites, on = 'group', how='left')
group_z_test_favorites
# Out:
#             group  contacts_show  users_all
# 0  not_tips_click            881       3971
# 1      tips_click            100        322

# %%
z_test(group_z_test_favorites)
# Out:
# p-значение:  0.00026645646284051416
# Отвергаем нулевую гипотезу, между группами есть статистически значимые различия

# %% [markdown]
# Разница конверсий между пользователями, выбравшими рекомендованное объявление, и пользователями, не воспользовавшихся функцией рекомендованных объявлений, является статистически значимой, поэтому можно считать, что у групп разная конверсия.
